# %%
from docx import *
import copy

# %% [markdown]
# ## Helper Functions

# %%
def safe_point(doc_obj):
   if doc_obj is not None:
      return doc_obj.pt
   else: return None
   
def safe_tab(doc_obj):
   if doc_obj is not None:
      return abs(doc_obj)/91440
   else: return None

def batch_dict_update(dict, new_items_dict = 0, zipped_items = 0):
   if zipped_items != 0:
      raise NotImplementedError
   elif new_items_dict != 0:
      for k, v in new_items_dict.items():
         dict[k] = v
      return dict
         # print(dict)
   else:
      raise RuntimeError

#    #how to handle alphebetical groupings
#       #remove any that have 18pt size
#    #check all runs for anything bold that ISN'T a run[0]
#    if indents_bool and runs_bool_strict:
#       is_root = True
#       is_certain = True
#    elif indents_bool or runs_bool_lax:
#       is_root = True
#       is_certain = False
#    else:
#       is_root = False
#       is_certain = False  
#    # print({'is_root':is_root, 'is_certain':is_certain},(indents_bool,runs_bool_strict,runs_bool_lax),'\nend\n')
#    return (is_root, is_certain)


def check_for_targetted_indents(para, config = None):
   """
   Takes a paragraph sub dict and the attendent runs dict. 
   Returns: tuple   (indent_one, indent_0, neither)
         #OLD#dictionary with two boolean values keyed to: 'is_root' and 'is_certain'
   Note: Config functionality not implemented yet, or all that well prepped
   """
   # print("\npara_____________",para)
   # print(runs_dict)
   if config is not None:
      raise NotImplementedError
   else:
      config = {'lower_root_para_features': {
                                 # 'first_line_indent': 1, 
                                 # 'left_indent': 2, 
                                 'para_indent': 1,
                                 },
               'upper_root_para_features': {
                                 # 'first_line_indent': 2, 
                                 # 'left_indent': 2, 
                                 'para_indent': 0,
                                 }}
   bool_single_indent = [para['para_features'][k] == v for k,v in config['lower_root_para_features'].items()]
   if all(bool_single_indent):
      return (True, False, False) #indent_one, indent_0, neither
   bool_no_indent = [para['para_features'][k] == v for k,v in config['upper_root_para_features'].items()]
   if all(bool_no_indent):
      return (False, True, False) #indent_one, indent_0, neither
   
   return (False, False, True) #indent_one, indent_0, neither




def check_run_specific_font_features(runs_dict_entry, run_num, config = None):
   """
   Takes a paragraph sub dict and the attendent runs dict. 
   Returns: (bool, bool, bool, bool) #upper, mid, bold, reject
   Note: Config functionality not implemented yet, or all that well prepped
   """
   # print("\npara_____________",para)
   # print(runs_dict)
   if config is not None:
      raise NotImplementedError
   else:
      config = {
               'lower_root_runs_features': {'run_bold': True},

               'reject_runs_features': {'run_size_pt': 18.0},
               'upper_root_runs_features': {'run_size_pt': 12.0}}
   # print(runs_dict_entry)
   # print(runs_dict_entry['run_features'])
   reject_run = [runs_dict_entry['run_features'][k] == v for k,v in config['reject_runs_features'].items()]
   if all(reject_run):
      return (False, False, False, True) #upper, mid, bold, reject
   else: pass

   bool_bold = [runs_dict_entry['run_features'][k] == v for k,v in config['lower_root_runs_features'].items()]
   if all(bool_bold):
      return (False, False, True, False) #upper, mid, bold, reject
   else: pass

   if run_num == 0:
      try:
         begins_with_hyphen = runs_dict_entry['run_text'][0] is '-'
      except:
         return (False, False, False, False) #upper, mid, bold, reject
      upper_root_runs_features = [runs_dict_entry['run_features'][k] == v for k,v in config['upper_root_runs_features'].items()]
      if all(upper_root_runs_features): 
         if begins_with_hyphen: return (False, True, False, False) #upper, mid, bold, reject
         else: return (True, False, False, False) #upper, mid, bold, reject
      else:
         text = runs_dict_entry['run_text'].split(" ")[0]
         if text == text.upper() and text != text.lower():
            if begins_with_hyphen: return (False, True, False, False) #upper, mid, bold, reject
            else: return (True, False, False, False) #upper, mid, bold, reject
   
   return (False, False, False, False) #upper, mid, bold, reject
   

                                       #how to handle alphebetical groupings
                                          #remove any that have 18pt size
                                       #check all runs for anything bold that ISN'T a run[0]
                           #how to handle non_indented
                              #look just for the size
                              #check all run[0].text and see if text.UPPER == text
                           #???how to handle non_indented not right font size
                              #check all run[0].text and see if text.UPPER == text
                              #check if run[0].strip().split(' ')[0] is the same UPPER and plain.
                              #have doublecheck of no helv?

# %% [markdown]
# ## python-docx extraction & paragraph level features

# %%
filename = "Fula_Dictionary-repaired.docx"
# filename = "pasted_docx page 1.docx"
document = Document(filename)

do_save_file = False
out_name = "simplified_parsed_dict_COMPLETE_v1.txt"


stop = 0


paras_dict = {}
pdict = {}
for para in document.paragraphs:

   pdict["first_line_indent"] = int(safe_tab(para.paragraph_format.first_line_indent) or 0)


   pdict["left_indent"] = int(safe_tab(para.paragraph_format.left_indent) or 0)

   pdict["para_indent"] = pdict["left_indent"]-pdict["first_line_indent"]
   tabs = "\t"*pdict["para_indent"]
   # print(pdict["para_indent"])

   paras_dict[stop] = {
                     # "para":para,
                     "runs": [run for run in para.runs], 
                     "pretty_plain_text": f"{tabs} {para.text}",
                     "para_features": pdict.copy(), 
                     # "first_line_indent": pdict["first_line_indent"],
                     # "left_indent": pdict["left_indent"],
                     # "para_indent": pdict["para_indent"]
                      }
   stop +=1
   # if stop >=60:
      # break
del document

# %% [markdown]
# ## Iterate over DOCX with dict() Extractor

# %%
# from deepdiff import DeepDiff
upper_roots_only_dict = {}
inner_roots_only = {}
rooted_dict = {}


#parent root
   #create program to test for root
      #> assert ('first_line_indent': 2, 'left_indent': 2, 'para_indent': 0},)
      #> 'run_size_pt': 12.0
   #validation
      #only one of those are true
      #test #> str.strip() == str.strip().upper()
   #add root to root dict ......., and nest all following paras under it
      #validate
         #save count of children

#sub-root
   #program for subroot
      #> assert ('first_line_indent': 1, 'left_indent': 2, 'para_indent': 1},)
      #> one of the runs after this contains
         #> 'run_font_name': 'TmsRmn 10pt', 'run_bold': True
   #> validate structure
      #> this is always run 0?
      #> both of the above always co-occur.
for p in paras_dict.keys():
   runs = paras_dict[p]["runs"]
   i = 0
   d = {}
   dupes = []
   prev = None
   is_upper_root, is_upper_root_certain, is_inner_root, is_inner_root_certain = False, False, False, False
   for run in runs:

      features = {
            "run_font_name": run.font.name,
            "run_bold": run.bold,
            "run_italic": run.italic,
            "run_size_pt": safe_point(run.font.size),
            }

      same_as_prev = features == prev
      d[i] = {}
      d[i]["run_text"] = run.text

      if same_as_prev:
         dupes.append(i)
         d[i]["same_format_as_prev"] = True
         look_back_num_index = 1
         looking_at_a_dup = True

         while looking_at_a_dup:
            try:
               previous_run = d[i-look_back_num_index]
               if previous_run.get("same_format_as_prev",False):
                  look_back_num_index += 1
               else:
                  looking_at_a_dup = False
            except:
               break

         prev_index = i - look_back_num_index
         prev_text = previous_run["run_text"]

         new_text = prev_text + run.text
         d[prev_index]["run_text"] = new_text
         
      else:
         # d[i]["diffs_from_prev"] = DeepDiff(prev, features)
         prev = features.copy()
         d[i]['run_features'] = features
         d[i]['para_all_text'] = paras_dict[p]['pretty_plain_text']
         d[i]['para_features'] = paras_dict[p]['para_features']
         # d[i] = batch_dict_update(d[i],features)

      i += 1
   # new
   # text_from_runs = []
   indent_1, indent_0, neither_indent = check_for_targetted_indents(paras_dict[p])
   indexes_for_all_runs = d.copy().keys()
   

   for k in indexes_for_all_runs:
      if k in dupes:
         d.pop(k)
      else: 
         # pass
         # text_from_runs.append(d[k]['run_text'].strip())
         d[k]['run_text'] = d[k]['run_text'].strip()

         empty_root = not bool(rooted_dict)
         
         upper_root, middle_root, bold, reject_run = check_run_specific_font_features(d[k],k)
         # prev_inner_root = None
         if upper_root:
            d['upper_root'] = k #Note, can only be found on Run 0
            ###
            upper_roots_only_dict[p] = copy.deepcopy(d[k])
            rooted_dict[d[k]['run_text']] = {'index':(p,k), 
                                             'subordinate_content': {(p,k):d[k]}, #{p:d,p_n:d_n, '...':'...'},
                                             'subordinate_root':{},                
                                             'stats':{
                                                      'middle_root_count': 0,
                                                      'direct_inner_root_count': 0,
                                                      }
                                             }
            prev_upper_root = rooted_dict[d[k]['run_text']]
            prev_upper_middle_root = rooted_dict[d[k]['run_text']]
            prev_any_root = rooted_dict[d[k]['run_text']]
         elif middle_root:
            d['middle_root'] = k #Note, can only be found on Run 0
            # upper_roots_only_dict[p] = copy.deepcopy(d[k])
            prev_upper_root['subordinate_root'][d[k]['run_text']] = {
                                                'index':(p,k), 
                                                'subordinate_content': {(p,k):d[k]}, #{p:d,p_n:d_n, '...':'...'},
                                                'subordinate_root':{},                 
                                                'stats':{
                                                      # 'middle_root_count': 0,
                                                      'direct_inner_root_count': 0,
                                                      }
                                                }
            prev_upper_root['stats']['middle_root_count'] += 1
            
            # prev_upper_root = rooted_dict[rooted_dict[d[k]['run_text']]]
            prev_upper_middle_root = prev_upper_root['subordinate_root'][d[k]['run_text']]
            prev_any_root = prev_upper_root['subordinate_root'][d[k]['run_text']]
         elif bold:
            d['bold'] = k #Note, can be found on any run
            prev_upper_middle_root['subordinate_root'][d[k]['run_text']] = {
                                                'index':(p,k), 
                                                'subordinate_content': {(p,k):d[k]}, #{p:d,p_n:d_n, '...':'...'},
                                                # 'subordinate_root':{},                 
                                                # 'stats':{
                                                         # 'middle_root_count': 0,
                                                         # 'inner_root_count': 0,
                                                         # }
                                                }
            
            prev_upper_root['stats']['direct_inner_root_count'] += 1
            # prev_upper_root = rooted_dict[prev_upper_root_key]['subordinate_root'][d[k]['run_text']]
            # prev_upper_middle_root = prev_upper_root['subordinate_root'][d[k]['run_text']]
            prev_any_root = prev_upper_middle_root['subordinate_root'][d[k]['run_text']]
            prev_inner_root_key = d[k]['run_text']
            prev_inner_root_index = prev_any_root['index']
            inner_roots_only[prev_inner_root_key] = copy.deepcopy(prev_any_root)
         elif reject_run:
            d.pop(k) 
         else:  #subordinate content of the last root
            if empty_root:
               continue
            else: 
               prev_any_root['subordinate_content'][(p,k)] = d[k]
               if prev_inner_root_index == prev_any_root['index']:
                  inner_roots_only[prev_inner_root_key]['subordinate_content'][(p,k)] = d[k]

   
   paras_dict[p]["runs"] = d

# %%
if do_save_file:
      import json       
      with open(out_name,"w", encoding="utf-8") as data:  
            data.write(str(paras_dict))

# %%
# readable_dict = {}
# for k in paras_dict.keys():
#    readable_dict[k] = {"runs": k["runs"],
#    }
inner_roots_only
# rooted_dict
# Out:
# {'a': {'index': (5, 0),
#   'subordinate_content': {(5, 0): {'run_text': 'a',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t a  prn,sbj,sf  DFZH  Z<->',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (5, 1): {'run_text': 'prn,sbj,sf',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t a  prn,sbj,sf  DFZH  Z<->',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (5, 2): {'run_text': 'DFZH  Z<->',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t a  prn,sbj,sf  DFZH  Z<->',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (6, 0): {'run_text': 'you (sg.)',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t you (sg.)',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (7, 0): {'run_text': 'tu',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t tu',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  '-a': {'index': (8, 0),
#   'subordinate_content': {(8, 0): {'run_text': '-a',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t -a  suf,pos  F',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (8, 1): {'run_text': 'suf,pos',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t -a  suf,pos  F',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (8, 2): {'run_text': 'F',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t -a  suf,pos  F',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (9,
#     0): {'run_text': 'your (sg.) (only with certain nouns such as those which refer to close family members)', 'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None}, 'para_all_text': '\t\t your (sg.) (only with certain nouns such as those which refer to close family members)', 'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (10,
#     0): {'run_text': 'ton, ta, tes (seulement pour certains substantifs, tels ceux qui se rapportent aux membres de la proche famille)', 'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None}, 'para_all_text': '\t\t ton, ta, tes (seulement pour certains substantifs, tels ceux qui se rapportent aux membres de la proche famille)', 'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'aan': {'index': (84, 1),
#   'subordinate_content': {(84, 1): {'run_text': 'aan',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': ' AAN  aan  prn,ind  V. a',
#     'para_features': {'first_line_indent': 2,
#      'left_indent': 2,
#      'para_indent': 0}},
#    (84, 2): {'run_text': 'prn,ind  V. a',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': ' AAN  aan  prn,ind  V. a',
#     'para_features': {'first_line_indent': 2,
#      'left_indent': 2,
#      'para_indent': 0}}}},
#  'aɗa': {'index': (211, 1),
#   'subordinate_content': {(211, 1): {'run_text': 'aɗa',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': ' AƊA   aɗa  prn,sbj,lf  V. a',
#     'para_features': {'first_line_indent': 2,
#      'left_indent': 2,
#      'para_indent': 0}},
#    (211, 2): {'run_text': 'prn,sbj,lf  V. a',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': ' AƊA   aɗa  prn,sbj,lf  V. a',
#     'para_features': {'first_line_indent': 2,
#      'left_indent': 2,
#      'para_indent': 0}}}},
#  '-ɗaa, -ɗa': {'index': (4897, 1),
#   'subordinate_content': {(4897, 1): {'run_text': '-ɗaa, -ɗa',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': ' ƊA(A)  -ɗaa, -ɗa  prn,sbj  V. a',
#     'para_features': {'first_line_indent': 2,
#      'left_indent': 2,
#      'para_indent': 0}},
#    (4897, 2): {'run_text': 'prn,sbj  V. a',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': ' ƊA(A)  -ɗaa, -ɗa  prn,sbj  V. a',
#     'para_features': {'first_line_indent': 2,
#      'left_indent': 2,
#      'para_indent': 0}}}},
#  '-e': {'index': (20, 0),
#   'subordinate_content': {(20, 0): {'run_text': '-e',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t -e  prn,obj  F',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (20, 1): {'run_text': 'prn,obj',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t -e  prn,obj  F',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (20, 2): {'run_text': 'F',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t -e  prn,obj  F',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (21, 0): {'run_text': 'you (suffix used in certain grammatical conditions)',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t you (suffix used in certain grammatical conditions)',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (22,
#     0): {'run_text': 'te (suffixe employé dans certaines situations grammaticales)', 'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None}, 'para_all_text': '\t\t te (suffixe employé dans certaines situations grammaticales)', 'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'ma, maa': {'index': (23, 0),
#   'subordinate_content': {(23, 0): {'run_text': 'ma, maa',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t ma, maa  prn,obj  FZH  Z<->',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (23, 1): {'run_text': 'prn,obj',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t ma, maa  prn,obj  FZH  Z<->',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (23, 2): {'run_text': 'FZH  Z<->',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t ma, maa  prn,obj  FZH  Z<->',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (24, 0): {'run_text': 'you (sg.)',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t you (sg.)',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (25, 0): {'run_text': 'te',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t te',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'ma, maa, maaɗa': {'index': (26, 0),
#   'subordinate_content': {(26, 0): {'run_text': 'ma, maa, maaɗa',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t ma, maa, maaɗa  prn,pos  DFZH  Z<->',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (26, 1): {'run_text': 'prn,pos',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t ma, maa, maaɗa  prn,pos  DFZH  Z<->',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (26, 2): {'run_text': 'DFZH  Z<->',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t ma, maa, maaɗa  prn,pos  DFZH  Z<->',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (27, 0): {'run_text': 'your (sg.)',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t your (sg.)',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (28, 0): {'run_text': 'ton, ta, tes',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t ton, ta, tes',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'aadi': {'index': (30, 0),
#   'subordinate_content': {(30, 0): {'run_text': 'aadi',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t aadi (o) / aadiiji (ɗi)  DFCZT  C<->,Z<+>  [amaana]',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (30, 1): {'run_text': '(o) / aadiiji (ɗi)',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t aadi (o) / aadiiji (ɗi)  DFCZT  C<->,Z<+>  [amaana]',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (30, 2): {'run_text': 'DFCZT  C<->,Z<+>  [amaana]',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t aadi (o) / aadiiji (ɗi)  DFCZT  C<->,Z<+>  [amaana]',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (31,
#     0): {'run_text': 'agreement(FC), promise(F), convention(F), accord, pact(C), confidence(C); custom [alaada]', 'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None}, 'para_all_text': '\t\t agreement(FC), promise(F), convention(F), accord, pact(C), confidence(C); custom [alaada]', 'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (32,
#     0): {'run_text': 'serment(D), contrat(T), convention(Z), accord(CZ), pacte(C), confiance(C); coutume(Z) [alaada]', 'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None}, 'para_all_text': '\t\t serment(D), contrat(T), convention(Z), accord(CZ), pacte(C), confiance(C); coutume(Z) [alaada]', 'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'alaada': {'index': (254, 1),
#   'subordinate_content': {(254, 1): {'run_text': 'alaada',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': ' ALAADA  alaada  V. aad-',
#     'para_features': {'first_line_indent': 2,
#      'left_indent': 2,
#      'para_indent': 0}},
#    (254, 2): {'run_text': 'V. aad-',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': ' ALAADA  alaada  V. aad-',
#     'para_features': {'first_line_indent': 2,
#      'left_indent': 2,
#      'para_indent': 0}}}},
#  'aadondiral': {'index': (37, 0),
#   'subordinate_content': {(37, 0): {'run_text': 'aadondiral',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t aadondiral (ngal)  T  [kaɓɓondiral]',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (37, 1): {'run_text': '(ngal)',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t aadondiral (ngal)  T  [kaɓɓondiral]',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (37, 2): {'run_text': 'T  [kaɓɓondiral]',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t aadondiral (ngal)  T  [kaɓɓondiral]',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (38, 0): {'run_text': 'alliance',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t alliance',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (39, 0): {'run_text': 'alliance',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t alliance',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'aadondireede': {'index': (40, 0),
#   'subordinate_content': {(40, 0): {'run_text': 'aadondireede',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t aadondireede  v.pv+ext  T  [fiɓondireede]',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (40, 1): {'run_text': 'v.pv+ext',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t aadondireede  v.pv+ext  T  [fiɓondireede]',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (40, 2): {'run_text': 'T  [fiɓondireede]',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t aadondireede  v.pv+ext  T  [fiɓondireede]',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (41, 0): {'run_text': 'to make a contract',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t to make a contract',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (42, 0): {'run_text': 'contracter',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t contracter',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'Aadama': {'index': (44, 0),
#   'subordinate_content': {(44, 0): {'run_text': 'Aadama',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t Aadama  PN  DZ  Z<->',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (44, 1): {'run_text': 'PN',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t Aadama  PN  DZ  Z<->',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (44, 2): {'run_text': 'DZ  Z<->',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t Aadama  PN  DZ  Z<->',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (45, 0): {'run_text': "man's first name, Adam",
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': "\t\t man's first name, Adam",
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (46, 0): {'run_text': "prénom d'homme, Adam",
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': "\t\t prénom d'homme, Adam",
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'aadamanke(ejo)': {'index': (47, 0),
#   'subordinate_content': {(47, 0): {'run_text': 'aadamanke(ejo)',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t aadamanke(ejo) (o) / aadamankeeɓe (ɓe)  DCZ  C<FJ,FT,M>,Z<->  [ɓii-Aadama, neɗɗo, remme, tagaaɗo, tomotte]',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (47, 1): {'run_text': '(o) / aadamankeeɓe (ɓe)',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t aadamanke(ejo) (o) / aadamankeeɓe (ɓe)  DCZ  C<FJ,FT,M>,Z<->  [ɓii-Aadama, neɗɗo, remme, tagaaɗo, tomotte]',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (47,
#     2): {'run_text': 'DCZ  C<FJ,FT,M>,Z<->  [ɓii-Aadama, neɗɗo, remme, tagaaɗo, tomotte]', 'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0}, 'para_all_text': '\t aadamanke(ejo) (o) / aadamankeeɓe (ɓe)  DCZ  C<FJ,FT,M>,Z<->  [ɓii-Aadama, neɗɗo, remme, tagaaɗo, tomotte]', 'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (48, 0): {'run_text': 'human being',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t human being',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (49, 0): {'run_text': 'être humain',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t être humain',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'aade': {'index': (51, 0),
#   'subordinate_content': {(51, 0): {'run_text': 'aade',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t aade  (o)  Db',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (51, 1): {'run_text': '(o)',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t aade  (o)  Db',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (51, 2): {'run_text': 'Db',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t aade  (o)  Db',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (52, 0): {'run_text': 'human beings',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t human beings',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (53, 0): {'run_text': 'êtres humains',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t êtres humains',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'aafugol': {'index': (55, 0),
#   'subordinate_content': {(55, 0): {'run_text': 'aafugol',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t aafugol (ngol)  D',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (55, 1): {'run_text': '(ngol)',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t aafugol (ngol)  D',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (55, 2): {'run_text': 'D',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t aafugol (ngol)  D',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (56, 0): {'run_text': 'installation of a bed',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t installation of a bed',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (57, 0): {'run_text': "installation d'un lit",
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': "\t\t installation d'un lit",
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'aajaade, ajaade': {'index': (59, 0),
#   'subordinate_content': {(59, 0): {'run_text': 'aajaade, ajaade',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t aajaade, ajaade  v.mv  D  [mooɓ(u)de, faggaade, mubbude, wubbude]',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (59, 1): {'run_text': 'v.mv',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t aajaade, ajaade  v.mv  D  [mooɓ(u)de, faggaade, mubbude, wubbude]',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (59, 2): {'run_text': 'D  [mooɓ(u)de, faggaade, mubbude, wubbude]',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t aajaade, ajaade  v.mv  D  [mooɓ(u)de, faggaade, mubbude, wubbude]',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (60, 0): {'run_text': 'to amass',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t to amass',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (61, 0): {'run_text': 'amasser',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t amasser',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'aalude': {'index': (63, 0),
#   'subordinate_content': {(63, 0): {'run_text': 'aalude',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t aalude  v.av  Z',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (63, 1): {'run_text': 'v.av',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t aalude  v.av  Z',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (63, 2): {'run_text': 'Z',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t aalude  v.av  Z',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (64, 0): {'run_text': 'to split, dissociate',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t to split, dissociate',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (65, 0): {'run_text': 'fendre, dissocier',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t fendre, dissocier',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'aamde': {'index': (67, 0),
#   'subordinate_content': {(67, 0): {'run_text': 'aamde',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t aamde  v.av  D',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (67, 1): {'run_text': 'v.av',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t aamde  v.av  D',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (67, 2): {'run_text': 'D',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t aamde  v.av  D',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (68, 0): {'run_text': 'to start, create, trace the place for a dwelling',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t to start, create, trace the place for a dwelling',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (69,
#     0): {'run_text': "commencer, créer, tracer l'emplacement d'une habitation", 'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None}, 'para_all_text': "\t\t commencer, créer, tracer l'emplacement d'une habitation", 'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'aamtude': {'index': (71, 0),
#   'subordinate_content': {(71, 0): {'run_text': 'aamtude',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t aamtude  v.av+ext  D',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (71, 1): {'run_text': 'v.av+ext',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t aamtude  v.av+ext  D',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (71, 2): {'run_text': 'D',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t aamtude  v.av+ext  D',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (72, 0): {'run_text': 'to split, open (calabash)',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t to split, open (calabash)',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (73, 0): {'run_text': 'fendre, ouvrir (calebasse)',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t fendre, ouvrir (calebasse)',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'aamare, amare': {'index': (75, 0),
#   'subordinate_content': {(75, 0): {'run_text': 'aamare, amare',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t aamare, amare (nge)  DZx(Turner, 1989)  Z<M,A>  cf.:[sirge]',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (75, 1): {'run_text': '(nge)',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t aamare, amare (nge)  DZx(Turner, 1989)  Z<M,A>  cf.:[sirge]',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (75, 2): {'run_text': 'DZx(Turner, 1989)  Z<M,A>  cf.:[sirge]',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t aamare, amare (nge)  DZx(Turner, 1989)  Z<M,A>  cf.:[sirge]',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (76,
#     0): {'run_text': 'coloration of cattle; white cow with red spots; white cow with small colored spots(Turner, 1989)', 'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None}, 'para_all_text': '\t\t coloration of cattle; white cow with red spots; white cow with small colored spots(Turner, 1989)', 'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (77,
#     0): {'run_text': 'robe de vache(D); vache blanche tachetée de rouge(Z); vache blanche aux taches colorées', 'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None}, 'para_all_text': '\t\t robe de vache(D); vache blanche tachetée de rouge(Z); vache blanche aux taches colorées', 'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (78,
#     0): {'run_text': 'amare / amari (R<A>): white cow with red flanks ; vache blanche aux flancs rouges', 'run_features': {'run_font_name': 'TmsRmn 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0}, 'para_all_text': '\t\t amare / amari (R<A>): white cow with red flanks ; vache blanche aux flancs rouges', 'para_features': {'first_line_indent': 0,
#      'left_indent': 2,
#      'para_indent': 2}},
#    (79,
#     0): {'run_text': "(X<A(Jam'aare)>): (zebu) with a white coat spotted red or black ; (zébu) à robe blanche avec quelques taches rouges ou noires", 'run_features': {'run_font_name': 'TmsRmn 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0}, 'para_all_text': "\t\t (X<A(Jam'aare)>): (zebu) with a white coat spotted red or black ; (zébu) à robe blanche avec quelques taches rouges ou noires", 'para_features': {'first_line_indent': 0,
#      'left_indent': 2,
#      'para_indent': 2}}}},
#  'aamin, aamiina': {'index': (81, 0),
#   'subordinate_content': {(81, 0): {'run_text': 'aamin, aamiina',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t aamin, aamiina    DZ  Z<A,M>',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (81, 1): {'run_text': '',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t aamin, aamiina    DZ  Z<A,M>',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (81, 2): {'run_text': 'DZ  Z<A,M>',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t aamin, aamiina    DZ  Z<A,M>',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (82, 0): {'run_text': 'so be it, amen!',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t so be it, amen!',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (83, 0): {'run_text': 'ainsi soit-il, amen!',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t ainsi soit-il, amen!',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'aar': {'index': (86, 0),
#   'subordinate_content': {(86, 0): {'run_text': 'aar',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t aar  n.  T',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (86, 1): {'run_text': 'n.',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t aar  n.  T',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (86, 2): {'run_text': 'T',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t aar  n.  T',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (87, 0): {'run_text': 'are (100 square meters)',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t are (100 square meters)',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (88, 0): {'run_text': 'are (100 metres carrés)',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t are (100 metres carrés)',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'aare ?': {'index': (90, 0),
#   'subordinate_content': {(90, 0): {'run_text': 'aare ?',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t aare ?  n.  (Imperato, 1973)',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (90, 1): {'run_text': 'n.',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t aare ?  n.  (Imperato, 1973)',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (90, 2): {'run_text': '(Imperato, 1973)',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t aare ?  n.  (Imperato, 1973)',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (91, 0): {'run_text': 'part of a design woven in',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t part of a design woven in kaasa blankets including diamond shapes',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (91, 1): {'run_text': 'kaasa',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t\t part of a design woven in kaasa blankets including diamond shapes',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (91, 2): {'run_text': 'blankets including diamond shapes',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t part of a design woven in kaasa blankets including diamond shapes',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (92, 0): {'run_text': 'partie de dessin tissé dans des couvertures',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t partie de dessin tissé dans des couvertures kaasa comprenant des formes de diamant',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (92, 1): {'run_text': 'kaasa',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t\t partie de dessin tissé dans des couvertures kaasa comprenant des formes de diamant',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (92, 2): {'run_text': 'comprenant des formes de diamant',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t partie de dessin tissé dans des couvertures kaasa comprenant des formes de diamant',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'aarude': {'index': (93, 0),
#   'subordinate_content': {(93, 0): {'run_text': 'aarude',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t aarude  v.av  ZH  Z<FT,M>',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (93, 1): {'run_text': 'v.av',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t aarude  v.av  ZH  Z<FT,M>',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (93, 2): {'run_text': 'ZH  Z<FT,M>',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t aarude  v.av  ZH  Z<FT,M>',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (94,
#     0): {'run_text': 'to split; to half-open a cashbox by lifting the lid; to open a ring', 'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None}, 'para_all_text': '\t\t to split; to half-open a cashbox by lifting the lid; to open a ring', 'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (95,
#     0): {'run_text': 'fendre(H); entrouvrir une caisse en soulevant le couvercle(Z); ouvrir un anneau(Z)', 'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None}, 'para_all_text': '\t\t fendre(H); entrouvrir une caisse en soulevant le couvercle(Z); ouvrir un anneau(Z)', 'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'aartude': {'index': (97, 0),
#   'subordinate_content': {(97, 0): {'run_text': 'aartude',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t aartude  v.av+ext  DY',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (97, 1): {'run_text': 'v.av+ext',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t aartude  v.av+ext  DY',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (97, 2): {'run_text': 'DY',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t aartude  v.av+ext  DY',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (98, 0): {'run_text': 'to split, separate',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t to split, separate',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (99, 0): {'run_text': 'fendre(D), séparer(D), écarter(Y)',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t fendre(D), séparer(D), écarter(Y)',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'Aaraabo, Aarabo': {'index': (101, 0),
#   'subordinate_content': {(101, 0): {'run_text': 'Aaraabo, Aarabo',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': "\t Aaraabo, Aarabo (o) / Aaraɓɓe, Aaraɓe'en (ɓe)  DFcz  CZ<G,A>  [Araabo/Araaɓe]:W  [Ara(a)buujo, Laarabuujo]",
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (101, 1): {'run_text': "(o) / Aaraɓɓe, Aaraɓe'en (ɓe)",
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': "\t Aaraabo, Aarabo (o) / Aaraɓɓe, Aaraɓe'en (ɓe)  DFcz  CZ<G,A>  [Araabo/Araaɓe]:W  [Ara(a)buujo, Laarabuujo]",
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (101,
#     2): {'run_text': 'DFcz  CZ<G,A>  [Araabo/Araaɓe]:W  [Ara(a)buujo, Laarabuujo]', 'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0}, 'para_all_text': "\t Aaraabo, Aarabo (o) / Aaraɓɓe, Aaraɓe'en (ɓe)  DFcz  CZ<G,A>  [Araabo/Araaɓe]:W  [Ara(a)buujo, Laarabuujo]", 'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (102, 0): {'run_text': 'Arab',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t Arab',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (103, 0): {'run_text': 'Arabe',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t Arabe',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'aaraaɓere, aaraaɓuure': {'index': (104, 0),
#   'subordinate_content': {(104, 0): {'run_text': 'aaraaɓere, aaraaɓuure',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t aaraaɓere, aaraaɓuure (nde)  - var.- arabiya(nkoore)  Z',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (104, 1): {'run_text': '(nde)  - var.- arabiya(nkoore)',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t aaraaɓere, aaraaɓuure (nde)  - var.- arabiya(nkoore)  Z',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (104, 2): {'run_text': 'Z',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t aaraaɓere, aaraaɓuure (nde)  - var.- arabiya(nkoore)  Z',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}}}},
#  'Arabuujo, Araabuujo': {'index': (105, 0),
#   'subordinate_content': {(105, 0): {'run_text': 'Arabuujo, Araabuujo',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t Arabuujo, Araabuujo (o) / Arabuuɓe, Araabuɓe (ɓe)  - var.- Aaraabo  Z  <FJ,M>',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (105, 1): {'run_text': '(o) / Arabuuɓe, Araabuɓe (ɓe)  - var.- Aaraabo',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t Arabuujo, Araabuujo (o) / Arabuuɓe, Araabuɓe (ɓe)  - var.- Aaraabo  Z  <FJ,M>',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (105, 2): {'run_text': 'Z  <FJ,M>',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t Arabuujo, Araabuujo (o) / Arabuuɓe, Araabuɓe (ɓe)  - var.- Aaraabo  Z  <FJ,M>',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}}}},
#  'arabiya, arabiyankoore': {'index': (106, 0),
#   'subordinate_content': {(106, 0): {'run_text': 'arabiya, arabiyankoore',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t arabiya, arabiyankoore (nde)  DZW  Z<+>  [aaraaɓere, aaraaɓuure]',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (106, 1): {'run_text': '(nde)',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t arabiya, arabiyankoore (nde)  DZW  Z<+>  [aaraaɓere, aaraaɓuure]',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (106, 2): {'run_text': 'DZW  Z<+>  [aaraaɓere, aaraaɓuure]',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t arabiya, arabiyankoore (nde)  DZW  Z<+>  [aaraaɓere, aaraaɓuure]',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
# ...
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (3342, 1): {'run_text': '(ngal)',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t coyoolal (ngal)  D',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (3342, 2): {'run_text': 'D',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t coyoolal (ngal)  D',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (3343, 0): {'run_text': 'species of bird',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t species of bird',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (3344, 0): {'run_text': "espèce d'oiseau",
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': "\t\t espèce d'oiseau",
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'coƴƴaaka': {'index': (3346, 0),
#   'subordinate_content': {(3346, 0): {'run_text': 'coƴƴaaka',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t coƴƴaaka  (ka)  i(Itinérances, 1981)(Imperato, 1973)',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (3346, 1): {'run_text': '(ka)',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t coƴƴaaka  (ka)  i(Itinérances, 1981)(Imperato, 1973)',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (3346, 2): {'run_text': 'i(Itinérances, 1981)(Imperato, 1973)',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t coƴƴaaka  (ka)  i(Itinérances, 1981)(Imperato, 1973)',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (3347, 0): {'run_text': 'type of',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t type of kaasa blanket',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (3347, 1): {'run_text': 'kaasa',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t\t type of kaasa blanket',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (3347, 2): {'run_text': 'blanket',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t type of kaasa blanket',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (3348, 0): {'run_text': 'sorte de couverture',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t sorte de couverture kaasa',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (3348, 1): {'run_text': 'kaasa',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t\t sorte de couverture kaasa',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'cuɓaaɗo': {'index': (25654, 0),
#   'subordinate_content': {(25654, 0): {'run_text': 'cuɓaaɗo',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t cuɓaaɗo (o)  D',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (25654, 1): {'run_text': '(o)',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t cuɓaaɗo (o)  D',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (25654, 2): {'run_text': 'D',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t cuɓaaɗo (o)  D',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (25655, 0): {'run_text': 'person who is chosen',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t person who is chosen',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (25656, 0): {'run_text': 'qui est choisi',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t qui est choisi',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'cuɓɓe': {'index': (3351, 0),
#   'subordinate_content': {(3351, 0): {'run_text': 'cuɓɓe',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t cuɓɓe  n.  D',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (3351, 1): {'run_text': 'n.',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t cuɓɓe  n.  D',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (3351, 2): {'run_text': 'D',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t cuɓɓe  n.  D',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (3352, 0): {'run_text': 'type of fruit',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t type of fruit',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (3353, 0): {'run_text': 'sorte de fruit',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t sorte de fruit',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'cuɓɗi; cuɓe; cuɓi; cuɓirɗum; cuɓirgal': {'index': (3354, 1),
#   'subordinate_content': {(3354,
#     1): {'run_text': 'cuɓɗi; cuɓe; cuɓi; cuɓirɗum; cuɓirgal', 'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None}, 'para_all_text': ' CUƁƊI  cuɓɗi; cuɓe; cuɓi; cuɓirɗum; cuɓirgal  V. suɓ-', 'para_features': {'first_line_indent': 2,
#      'left_indent': 2,
#      'para_indent': 0}},
#    (3354, 2): {'run_text': 'V. suɓ-',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': ' CUƁƊI  cuɓɗi; cuɓe; cuɓi; cuɓirɗum; cuɓirgal  V. suɓ-',
#     'para_features': {'first_line_indent': 2,
#      'left_indent': 2,
#      'para_indent': 0}}}},
#  'cuddaaje; cuddamaaje': {'index': (3355, 1),
#   'subordinate_content': {(3355, 1): {'run_text': 'cuddaaje; cuddamaaje',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': ' CUDDAAJE  cuddaaje; cuddamaaje  V. sudd-',
#     'para_features': {'first_line_indent': 2,
#      'left_indent': 2,
#      'para_indent': 0}},
#    (3355, 2): {'run_text': 'V. sudd-',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': ' CUDDAAJE  cuddaaje; cuddamaaje  V. sudd-',
#     'para_features': {'first_line_indent': 2,
#      'left_indent': 2,
#      'para_indent': 0}}}},
#  'cuddu': {'index': (3357, 0),
#   'subordinate_content': {(3357, 0): {'run_text': 'cuddu',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t cuddu  n.  D  [cuddi (ndi)/ cuddiiji (ɗi)]:Z<-> [kippu]',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (3357, 1): {'run_text': 'n.',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t cuddu  n.  D  [cuddi (ndi)/ cuddiiji (ɗi)]:Z<-> [kippu]',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (3357, 2): {'run_text': 'D  [cuddi (ndi)/ cuddiiji (ɗi)]:Z<-> [kippu]',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t cuddu  n.  D  [cuddi (ndi)/ cuddiiji (ɗi)]:Z<-> [kippu]',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (3358, 0): {'run_text': 'mist, fog',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t mist, fog',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (3359, 0): {'run_text': 'brume',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t brume',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'cukaaku; cukalel/cukaloy': {'index': (3360, 1),
#   'subordinate_content': {(3360, 1): {'run_text': 'cukaaku; cukalel/cukaloy',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': ' CUKAAKU  cukaaku; cukalel/cukaloy  V. suk-',
#     'para_features': {'first_line_indent': 2,
#      'left_indent': 2,
#      'para_indent': 0}},
#    (3360, 2): {'run_text': 'V. suk-',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': ' CUKAAKU  cukaaku; cukalel/cukaloy  V. suk-',
#     'para_features': {'first_line_indent': 2,
#      'left_indent': 2,
#      'para_indent': 0}}}},
#  'cukkeeki; cukkiri/cukke; cukkoori': {'index': (3361, 1),
#   'subordinate_content': {(3361,
#     1): {'run_text': 'cukkeeki; cukkiri/cukke; cukkoori', 'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None}, 'para_all_text': ' CUKKEEKI  cukkeeki; cukkiri/cukke; cukkoori  V. sukk- (1)', 'para_features': {'first_line_indent': 2,
#      'left_indent': 2,
#      'para_indent': 0}},
#    (3361, 2): {'run_text': 'V. sukk- (1)',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': ' CUKKEEKI  cukkeeki; cukkiri/cukke; cukkoori  V. sukk- (1)',
#     'para_features': {'first_line_indent': 2,
#      'left_indent': 2,
#      'para_indent': 0}}}},
#  'cukko': {'index': (25739, 0),
#   'subordinate_content': {(25739, 0): {'run_text': 'cukko',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t cukko (o)  T(Kane and Robinson, 1984)  (Kane and Robinson, 1984)<FT>  [dewo]',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (25739, 1): {'run_text': '(o)',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t cukko (o)  T(Kane and Robinson, 1984)  (Kane and Robinson, 1984)<FT>  [dewo]',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (25739,
#     2): {'run_text': 'T(Kane and Robinson, 1984)  (Kane and Robinson, 1984)<FT>  [dewo]', 'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0}, 'para_all_text': '\t cukko (o)  T(Kane and Robinson, 1984)  (Kane and Robinson, 1984)<FT>  [dewo]', 'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (25740, 0): {'run_text': 'deputy',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t deputy',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (25741, 0): {'run_text': 'adjoint',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t adjoint',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  'cukkol/cukki': {'index': (3363, 1),
#   'subordinate_content': {(3363, 1): {'run_text': 'cukkol/cukki',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': ' CUKKOL  cukkol/cukki  V. sukk- (2)',
#     'para_features': {'first_line_indent': 2,
#      'left_indent': 2,
#      'para_indent': 0}},
#    (3363, 2): {'run_text': 'V. sukk- (2)',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': ' CUKKOL  cukkol/cukki  V. sukk- (2)',
#     'para_features': {'first_line_indent': 2,
#      'left_indent': 2,
#      'para_indent': 0}}}},
#  'cukke': {'index': (3365, 0),
#   'subordinate_content': {(3365, 0): {'run_text': 'cukke',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': True,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t cukke  n.  D',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (3365, 1): {'run_text': 'n.',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': True,
#      'run_size_pt': None},
#     'para_all_text': '\t cukke  n.  D',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (3365, 2): {'run_text': 'D',
#     'run_features': {'run_font_name': 'Helv 8pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': 8.0},
#     'para_all_text': '\t cukke  n.  D',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 2,
#      'para_indent': 1}},
#    (3366, 0): {'run_text': 'ill (person who is ?)',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t ill (person who is ?)',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}},
#    (3367, 0): {'run_text': 'malade',
#     'run_features': {'run_font_name': 'TmsRmn 10pt',
#      'run_bold': None,
#      'run_italic': None,
#      'run_size_pt': None},
#     'para_all_text': '\t\t malade',
#     'para_features': {'first_line_indent': 1,
#      'left_indent': 3,
#      'para_indent': 2}}}},
#  ...}
