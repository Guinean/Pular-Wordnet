# %%
# altair to visualize the data. read in pickle
# determine df shape for this to work
# import birdseye and snoop
import snoop
import altair as alt
# from vega_datasets import data
from typing import Optional, Dict, List, Any, Union, Tuple
import pydantic
from pydantic import ValidationError, validator, root_validator, Field, constr, BaseModel
from pydantic_docx import Docx_Paragraph_and_Runs, read_docx, extract_features #type:ignore
from pydantic_docx_processor import create_sized_dataframe, expand_dataframe #type:ignore
import re
import json
from itertools import compress, chain
from datetime import datetime
import pandas as pd
import numpy as np
from functools import partial

# %%
import pickle
with open('pickled_results/feature_Frames_and_Indexes.pkl', 'rb') as file:
    # Call load method to deserialze
    output = pickle.load(file, encoding='utf-8')
(
parsed_object_list, #:List[Tuple[int,Docx_Paragraph_and_Runs]]
parsed_object_lookup, #:Dict[int,Docx_Paragraph_and_Runs] = dict(parsed_object_list)
doc_para_count, #: int = int(parsed_to_dict['total_encountered_paragraphs']) #type: ignore
char_counts, #: Counter = parsed_to_dict['char_counts'] #type: ignore
rootFrame,#:pd.DataFrame
rootsubpieceFrame, #:pd.DataFrame
lemmaFrame, #:pd.DataFrame
nonentityParaFrame, #pd.DataFrame
cleanerOutcomesDf #pd.DataFrame
    ) = output
paratext_lookup = {k:v.interogate__para_text() for k,v in parsed_object_lookup.items()}

# %%
with open('pickled_results/all_inheritance_frames_tup.pkl', 'rb') as file:
    # Call load method to deserialze
    output = pickle.load(file, encoding='utf-8')
# print(output)
(
allParagraphsInheritanceFrame,
entityDeclarationParas,
paragraphRecordsFrame
) = output
# print(type(allParagraphsInheritanceFrame))
all_inheritance_frames_dict = {
   'allParagraphsInheritanceFrame':allParagraphsInheritanceFrame,
   'entityDeclarationParas':entityDeclarationParas,
   'paragraphRecordsFrame':paragraphRecordsFrame
}

# %%
paragraphRecordsFrame
# entityDeclarationParas
# Out:
#        paragraphIndex_root is_root    text_root mask_root run_text_list_root  \
# index
# 6                      4.0    root            A    [True]                [A]
# 7                      4.0    root            A    [True]                [A]
# 9                      4.0    root            A    [True]                [A]
# 10                     4.0    root            A    [True]                [A]
# 12                     4.0    root            A    [True]                [A]
# ...                    ...     ...          ...       ...                ...
# 32498              32495.0    root        ƳUUW-    [True]            [ƳUUW-]
# 32501              32499.0    root        ƳUUƳ-    [True]            [ƳUUƳ-]
# 32502              32499.0    root        ƳUUƳ-    [True]            [ƳUUƳ-]
# 32505              32503.0    root  ƳUUƳ-  (2?)    [True]      [ƳUUƳ-  (2?)]
# 32506              32503.0    root  ƳUUƳ-  (2?)    [True]      [ƳUUƳ-  (2?)]
#
#        paragraphIndex_root_subpiece is_root_subpiece text_root_subpiece  \
# index
# 6                               NaN              NaN                NaN
# 7                               NaN              NaN                NaN
# 9                               NaN              NaN                NaN
# 10                              NaN              NaN                NaN
# 12                              NaN              NaN                NaN
# ...                             ...              ...                ...
# 32498                           NaN              NaN                NaN
# 32501                           NaN              NaN                NaN
# 32502                           NaN              NaN                NaN
# 32505                           NaN              NaN                NaN
# 32506                           NaN              NaN                NaN
#
#       mask_root_subpiece run_text_list_root_subpiece  paragraphIndex_lemma  \
# index
# 6                    NaN                         NaN                   5.0
# 7                    NaN                         NaN                   5.0
# 9                    NaN                         NaN                   8.0
# 10                   NaN                         NaN                   8.0
# 12                   NaN                         NaN                  11.0
# ...                  ...                         ...                   ...
# 32498                NaN                         NaN               32496.0
# 32501                NaN                         NaN               32500.0
# 32502                NaN                         NaN               32500.0
# 32505                NaN                         NaN               32504.0
# 32506                NaN                         NaN               32504.0
#
#       is_lemma text_lemma            mask_lemma  \
# index
# 6        lemma          a  [True, False, False]
# 7        lemma          a  [True, False, False]
# 9        lemma         -a  [True, False, False]
# 10       lemma         -a  [True, False, False]
# 12       lemma        aan  [True, False, False]
# ...        ...        ...                   ...
# 32498    lemma   ƴuuwaade  [True, False, False]
# 32501    lemma    ƴuuƴude  [True, False, False]
# 32502    lemma    ƴuuƴude  [True, False, False]
# 32505    lemma    ƴuuƴude  [True, False, False]
# 32506    lemma    ƴuuƴude  [True, False, False]
#
#                                  run_text_list_lemma  paragraphIndex  \
# index
# 6                    [a  , prn,sbj,sf  , DFZH  Z<->]             6.0
# 7                    [a  , prn,sbj,sf  , DFZH  Z<->]             7.0
# 9                               [-a  , suf,pos  , F]             9.0
# 10                              [-a  , suf,pos  , F]            10.0
# 12               [aan  , prn,ind  , DFZH  [an]:Z<->]            12.0
# ...                                              ...             ...
# 32498  [ƴuuwaade  , v.mv  , D  [ƴuubaade, ƴooraade]]         32498.0
# 32501                         [ƴuuƴude  , v.av  , D]         32501.0
# 32502                         [ƴuuƴude  , v.av  , D]         32502.0
# 32505                         [ƴuuƴude  , v.av  , D]         32505.0
# 32506                         [ƴuuƴude  , v.av  , D]         32506.0
#
#                                  run_text_list_paragraph run_enumerated_root  \
# index
# 6                                            [you (sg.)]                 [0]
# 7                                                   [tu]                 [0]
# 9      [your (sg.) (only with certain nouns such as t...                 [0]
# 10     [ton, ta, tes (seulement pour certains substan...                 [0]
# 12                                [you (sg.) (emphatic)]                 [0]
# ...                                                  ...                 ...
# 32498                            [s'incliner; se cabrer]                 [0]
# 32501                            [to increase in volume]                 [0]
# 32502                              [augmenter de volume]                 [0]
# 32505  [to give (push with?) the head to get out ?; t...                 [0]
# 32506        [donner (de?) la tête pour sortir; gonfler]                 [0]
#
#       run_enumerated_root_subpiece run_enumerated_lemma
# index
# 6                              NaN            [0, 1, 2]
# 7                              NaN            [0, 1, 2]
# 9                              NaN            [0, 1, 2]
# 10                             NaN            [0, 1, 2]
# 12                             NaN            [0, 1, 2]
# ...                            ...                  ...
# 32498                          NaN            [0, 1, 2]
# 32501                          NaN            [0, 1, 2]
# 32502                          NaN            [0, 1, 2]
# 32505                          NaN            [0, 1, 2]
# 32506                          NaN            [0, 1, 2]
#
# [16807 rows x 20 columns]

# %%
entityDeclarationParas.loc[11,:]
# Out:
# is_any_entity                                              lemma
# is_any_root                                                 root
# is_main_root                                                root
# lemma_run_numbers                                            NaN
# mask_any_entity                             [True, False, False]
# mask_any_root                                             [True]
# mask_main_root                                            [True]
# paragraphIndex_any_entity                                   11.0
# paragraphIndex_any_root                                      4.0
# paragraphIndex_main_root                                     4.0
# run_text_list_any_entity     [aan  , prn,ind  , DFZH  [an]:Z<->]
# run_text_list_any_root                                       [A]
# run_text_list_main_root                                      [A]
# text_any_entity                                              aan
# text_any_root                                                  A
# text_main_root                                                 A
# paragraphIndex                                               NaN
# Name: 11, dtype: object

# %%
workinglemmas = paragraphRecordsFrame.groupby(['paragraphIndex_root','paragraphIndex_root_subpiece','paragraphIndex_lemma'])
ct_all_lemmas_with_dependent_paragraphs = len(workinglemmas)
print(ct_all_lemmas_with_dependent_paragraphs)
workinglemmas = {k:list(v) for k,v in workinglemmas.groups.items() if len(v) >=2}
ct_all_lemmas_with_2plus_dependnet_paragraphs = len(workinglemmas)
print(ct_all_lemmas_with_2plus_dependnet_paragraphs)
# Out:
# 7994
# 7985

# %%
sorted(list(workinglemmas.items()))[:5]
# Out:
# [((4.0, nan, 5.0), [6, 7]),
#  ((4.0, nan, 8.0), [9, 10]),
#  ((4.0, nan, 11.0), [12, 13]),
#  ((4.0, nan, 14.0), [15, 16]),
#  ((4.0, nan, 17.0), [18, 19])]

# %%
def getAssert(dct,val,typ:type, strict = True) -> Any:
   out = dct.get(val,None)
   if strict and typ is type(None):
      raise NotImplementedError(f'this get/assert function cannot "get" None values safely, and a {val} type was passed for dict {dict}')
   if strict and out is None:
      raise KeyError(f"the provided dict {dct} did not have the key: {val}")
   assert isinstance(out,typ), f"the provided dict {dct} did not give {val} with the expected type: {typ}, but instead {out}"
   return out
   
def trustyGet(obj:Docx_Paragraph_and_Runs, feat: str, silent_return = True) -> str:
      if not silent_return:
         output : str = getattr(obj,feat,'')
         if len(output) > 0:
            return output
         else:
            raise AttributeError(f'trusty getter could not find: {feat}')
      else:
         output : str = getattr(obj,feat,'')
         return output

# %%
class dict_entry(pydantic.BaseModel): 
   '''
   #True is used as default value, and must be changed to False if the feature is not found. This will catch not implemented, and incomplete updates
   '''
   irregularities: List[str] = []
   lemma_index: int 
   
   lemma: str = Field(...,min_length = 1) #article
   root: str
   root_subpiece: Union[str,bool] = True #these will not be updated after initialization
   root_metadata: Dict[str,Any]  #index,root_text, root_meta_data #article 
   root_origin: Union[str,bool] = True #these will not be updated after initialization
   #Paragraph Derivatives: Glosses and Annotations
   lemmaLine_runs: List[str] #these will not be updated after initialization
   englishGlossLine_runs: Union[List[str],bool] = True #these will not be updated after initialization
   frenchGlossLine_runs: Union[List[str],bool] = True #these will not be updated after initialization
   FulaAnnotations_runs: Union[List[List[str]],bool]= True #these will not be updated after initialization

   #Gloss Derivatives: English Senses
   FulaSenseEnglish: Union[List[str],bool] = True #list of "senses" split by semicolons #article
   FulaSenseEnglish_Count: Union[int,bool] = True #number of senses in english #aka FulaSenseClassifications #article
   FulaSenseEnglish_Annotations: Union[List[str],bool] = True #contains the annotations (in parenthesis) for a given sense, if any #article 
   FulaSenseEnglish_Synonyms: Union[List[str],bool] = True #holds bracket text for a sense, suspected all synonyms. These may all occur at the end, and may be redundant with the synonyms provided at the head of the entry
   FulaSenseEnglish_unusedContent: Union[List[str],bool] = True #holds any run text that is not contained in the above features
   
   #Gloss Derivatives: French Senses
   FulaSenseFrench: Union[List[str],bool] = True #article
   FulaSenseFrench_Count: Union[int,bool] = True #aka FulaSenseClassifications
   FulaSenseFrench_Annotations: Union[List[str],bool] = True
   FulaSenseFrench_Synonyms: Union[List[str],bool] = True
   FulaSenseFrench_unusedContent: Union[List[str],bool] = True
   
   #lemma derivative
   lemmaLine_unusedContent: List[Tuple[int,str]] #= Field(...) #int is index for run to allow tracing as entries are removed
   FulaDialects: Union[List[str],bool] = True #article
   FulaPOSTags: Union[List[str],bool] = True #article
   FulaPOSClass: Union[List[str],bool] = True #Noun, Adj, Verb, Adv, Prn, ..., Complicated, Indeterminate
   FulaNoun_NounsAndClass: Union[List[Tuple[str,str]],bool] = True #Pular has unique noun classes. Lemma will be copied here beside its class ("noun", "nounclass"), and any additional singular forms will be in additional tuples in this same list
   FulaNoun_PluralsAndClass: Union[List[str],bool] = True #temporary measure #TODO. include list of wordclasses find all and not '/' findall #Union[List[Tuple[str,str]],bool] = True #Dict provides plurals for nouns. Tuples will have ("noun", "nounclass")
   FulaSynonyms: Union[List[str],bool] = True #article
   FulaCrossRef: Union[List[str],bool] = True
         # FulaVerbClass:
   #paras
   paragraphs: List[Docx_Paragraph_and_Runs] = Field(...,min_items = 1)
   
   class Config:
      validate_all = True
      # validate_assignment = True
      smart_union = True  
      extra = 'forbid'

   @root_validator(pre=True)
   def _validate_and_build(cls, values: Dict[str,Any]) -> Dict[str, Any]:
      # print(values)
      newValues: Dict[str,Any] = {}
      newValues['irregularities'] = []

      ###PARAGRAPHS CHECK###
      # print(values)
      newValues['paragraphs'] = getAssert(values,'paragraphs',list) #these come in as tuples(ind,para)
      #TODO have more rigorous checks on para since so much depends on that even in this validation
      assert isinstance(newValues['paragraphs'][0],tuple), 'currently paras must be packaged in a tuple with their original doc index'
      newValues['paragraphs'] = [p for i,p in newValues['paragraphs']]
      if len(newValues['paragraphs']) == 0:
         raise ValueError('given invalid paragraphs of zero length')
      else: #logic for subsidary paragraphs
         lemma_line = trustyGet(newValues['paragraphs'][0],feat = 'run_text', silent_return=False)
         newValues['lemmaLine_runs'] = lemma_line
         if len(newValues['paragraphs']) <3:
            raise ValueError('incorrect number of paragraphs provided')
         elif len(newValues['paragraphs']) == 3:
            newValues['englishGlossLine_runs'] = newValues['paragraphs'][1].get_run_text()
            newValues['frenchGlossLine_runs'] = newValues['paragraphs'][2].get_run_text()
         else: 
            newValues['englishGlossLine_runs'] = newValues['paragraphs'][1].get_run_text()
            newValues['frenchGlossLine_runs'] = newValues['paragraphs'][2].get_run_text()
            newValues['FulaAnnotations_runs'] = []
            for p in newValues['paragraphs'][3:]:
               # print(p.get_run_text())
               newValues['FulaAnnotations_runs'].append(p.get_run_text())
          
      try: ###LEMMA CHECK###
         #reading in lemma results from first pass of pydantic parser
         lemma_index, lemma_mask, lemmaLine_runs = getAssert(values,'lemma',tuple)
         #checking for correct structure
         lemma_matched_runs = list(compress(lemmaLine_runs,lemma_mask))
         if len(lemma_matched_runs) > 1:
            newValues['irregularities'].append('What:Unexpected, Where: Lemmas, Why: the merge routines should aggregate adjacent runs with same features. Multiple Lemma runs should not be possible if Bold is contiguous')
         lemma_text = ''.join(chain(lemma_matched_runs)).strip()
            #TODO have better control for expected structure that these runs should be adjacent (and only should be one)
         #saving values. These will have to pass type check of declared attribute types for validation to succeed
         newValues['lemma'] = lemma_text
         newValues['lemma_index'] = lemma_index
         newValues['lemmaLine_runs'] = lemmaLine_runs
         # first_lemma = False
         used_run_mask = [False]*len(lemma_mask)
         for i,b in enumerate(lemma_mask):
            if b:
               used_run_mask[i]=True

      except Exception as e:
         #exception lemma check
         raise RuntimeError('failed lemma check') from e

      try: ###ROOT CHECK###
         #reading in root results from first pass of pydantic parser
         #checking for correct structure
         root_index, root_mask, rootLine_runs = getAssert(values,'root',tuple)
         root_matched_runs = list(compress(rootLine_runs,root_mask))
         if len(root_matched_runs) > 1:
            newValues['irregularities'].append('What:Unexpected, Where: Root, Why: the merge routines should aggregate adjacent runs with same features. Multiple Root runs should not be possible if Fontsize is contiguous and unique')
         root_text = ''.join(chain(root_matched_runs)).strip()
         if root_index == newValues['lemma_index']:
            newValues['irregularities'].append('What:inconsistent, Where: Lemmas and Root, Why:normally root and lemma are on different lines. This has them sharing, which may indicate a lack of other content')
            used_run_mask = [any(run) for run in list(zip(used_run_mask,root_mask))]
            rootLine_runs = False
         newValues['root'] = root_text
         newValues['root_metadata'] = {'root_index': root_index, 'root_runs':rootLine_runs}
      except Exception as e:
         #exception ROOT check
         raise RuntimeError('failed ROOT check') from e

      try: ###ROOT-Subpiece CHECK###
         #iterating in case a subroot is present
         root_index, root_mask, rootLine_runs = getAssert(values,'root_subpiece',tuple)
         root_matched_runs = list(compress(rootLine_runs,root_mask))
         if len(root_matched_runs) > 1:
            newValues['irregularities'].append('What:Unexpected, Where: Root-Subpiece, Why: the merge routines should aggregate adjacent runs with same features. Multiple Root runs should not be possible if Fontsize is contiguous and unique')
         root_subpiece_text = ''.join(chain(root_matched_runs)).strip()
         if root_index == newValues['lemma_index']:
            newValues['irregularities'].append('What:inconsistent, Where: Lemmas and Root-Subpiece, Why:normally root and lemma are on different lines. This has them sharing, which may indicate a lack of other content')
            used_run_mask = [any(run) for run in list(zip(used_run_mask,root_mask))]
            rootLine_runs = False
         newValues['root_subpiece'] = root_subpiece_text
         newValues['root_metadata'] = {'root_subpiece_index': root_index, 'root_subpiece_runs':rootLine_runs}
      except AssertionError as e:
         newValues['root_subpiece'] = False
      except Exception as e:
         #exception ROOT-Subpiece check
         raise RuntimeError('failed ROOT-Subpiece check') from e

      #determining lemmaLine_unusedContent
      unused_run_mask = [not r for r in used_run_mask]
      newValues['lemmaLine_unusedContent'] = list(compress(enumerate(newValues['lemmaLine_runs']),unused_run_mask))
      return newValues

   def parse_senses(self):
      #TODO
      return

   def parse_glossRemainder(self):
      #TODO
      return

   def parse_lemmaLine(self):
      
      pos_config = {'docxFeature': 'run_italic',
               'strSummary':'fontItalic', 
               'value':True}
      (is_target, text, target_mask, run_text) = extract_features(self.paragraphs[0],pos_config)
      #POS
      if is_target:
         for i,b in enumerate(target_mask):
            if b:
               text = run_text[i] #TODO this only pulls POS info from the first contiguous italics run
               # print(text)
         #noun
            #regex () to remove FulaWordClass
            #regex / to get plural
            # regex n.
         word_class = re.findall(r"\(([^\)]+)\)",text) #anything between parenthesis
         # print(word_class)
         noun_flag = re.findall(r"(n\.)",text)
         plurals = re.findall(r"([^\/]+)",text) #anything not a /
         if any([len(word_class)>0, noun_flag, len(plurals)>1]):
            # print('here')
            is_noun = True
            self.FulaPOSClass = ['Noun']
            if word_class:
               self.FulaNoun_NounsAndClass = [(self.lemma,word_class[0])]
            if len(plurals)>1:
               # self.FulaNoun_NounsAndClass
               if len(plurals)>2:
                  print(self.lemma_index,' - index lemma has multiple noun slashes "/"')
               # plurals_word_class = re.findall("\(([^\)]+)\)",plurals[1])  #anything between parenthesis
               # plurals_text = re.findall("(?<![^\)])[^\(]+(?![^\(]*\))",plurals[1]) #anything NOT between ()
               self.FulaNoun_PluralsAndClass = plurals #TODO
            else:
               pass
         else:
            self.FulaNoun_NounsAndClass = False
            is_verb = bool(re.findall(r"v.",text.lower()))
            if is_verb:
               self.FulaPOSClass = ['Verb']
            self.FulaPOSTags = text.replace('+',',').split(',')

      #dialect
      dialects = []
      for run in self.lemmaLine_runs:
         dialects.extend(re.findall(r"\<([^\>]+)\>",run)) #anything between parenthesis
      if len(dialects)>0:
         self.FulaDialects = list(set(dialects))
      else:
         self.FulaDialects = 'Mali'
      #cross ref
         # cross_reference = r"cf\.\:(.+)|cf\:(.+)" #TODO
      #syn
         #TODO

      
      return

   def parse_lemmaLineRemainder(self):
      #TODO
      return

   def get_rootOrigin(self):
      #TODO
      return
 
   def give_entryText(self, joiner = '\t') -> str: #article
      return joiner.join([para.trustyGet('para_text') for para in self.paragraphs])

# %%
all_entries = []
for e in workinglemmas.items():
   values = {}
   root,root_subpiece,lemma = e[0]
   paras = e[1]
   # parsed_object_lookup[root]
   values['paragraphs']= [int(lemma)]+paras
   values['paragraphs'] = [(i,parsed_object_lookup[i]) for i in values['paragraphs']]
   # print(len(values['paragraphs']))
   lemma_mask = entityDeclarationParas.loc[int(lemma),:]['mask_any_entity']
   lemmaLine_runs = entityDeclarationParas.loc[int(lemma),:]['run_text_list_any_entity']
   values['lemma'] = (int(lemma),lemma_mask,lemmaLine_runs)
   root_mask = entityDeclarationParas.loc[int(root),:]['mask_any_entity']
   rootLine_runs = entityDeclarationParas.loc[int(root),:]['run_text_list_any_entity']
   values['root'] = (int(root),root_mask,rootLine_runs)
   if not np.isnan(root_subpiece):
      root_subpiece_mask = entityDeclarationParas.loc[int(root_subpiece),:]['mask_any_entity']
      root_subpieceLine_runs = entityDeclarationParas.loc[int(root_subpiece),:]['run_text_list_any_entity']
      values['root_subpiece'] = (int(root_subpiece),root_subpiece_mask,root_subpieceLine_runs)
   else:
      values['root_subpiece'] = False
   # print(values.get('paragraphs'))
   this_entry = dict_entry(**values)
   # print('here')
   # print(this_entry.json(indent=3))
   this_entry.parse_lemmaLine()
   all_entries.append(this_entry)

   # if len(all_entries)>40:
      # break
   # break
# pass

# %%
noun_entries = []
for e in all_entries:
   if e.FulaPOSClass == ['Noun']:
      # print(e)
      noun_entries.append(e)

verb_entries = []
for e in all_entries:
   if e.FulaPOSClass == ['Verb']:
      # print(e)
      verb_entries.append(e)

# %%
number_of_noun_entries = len(noun_entries)
number_of_verb_entries = len(verb_entries)
number_of_other_entries = len(all_entries)-len(verb_entries)-len(noun_entries)
number_of_total_entries = len(all_entries)

dictionary_numbers_dict = {"number_of_total_entries":number_of_total_entries,
"number_of_noun_entries":number_of_noun_entries,
"number_of_verb_entries":number_of_verb_entries,
"number_of_other_entries":number_of_other_entries,
}

print("number of lemma-identified paragraph clusters associated with 2 or more dependent content paragraphs: ",ct_all_lemmas_with_2plus_dependnet_paragraphs)
_ = [print('\t',k,v) for k,v in dictionary_numbers_dict.items()]
# Out:
# number of lemma-identified paragraph clusters associated with 2 or more dependent content paragraphs:  7985
# 	 number_of_total_entries 7985
# 	 number_of_noun_entries 4879
# 	 number_of_verb_entries 2672
# 	 number_of_other_entries 434

# %%
# codeclared lemmas and roots                1438 #<<<
# instances of non-lemma bold lines          40   #<<<

# true lemmas: 9610 - 40 =                   9570 #<<<
# true lemmas not co declared 9570 - 1438              
# lemmas with any paragraphs following       7994
7985

# %%
# # import birdseye as eye
# %load_ext birdseye
# https://birdseye.readthedocs.io/en/latest/integrations.html

# %%
# %%eye

# ...Preparing Pickle...
# root_subpiece                              713
# root                                       6381
# lemmas                                     9610
# num entities in the docx:                  16704
# num of overlapping entities in the docx:   1438
# paragraphs in the docx:                    32507
# non-entity paragraphs in the docx:         17241

co_declared_lemmas = 1438
bold_lines = 9610
non_leading_bold_lines = 40

all_lemmas = bold_lines - non_leading_bold_lines
print(all_lemmas)
non_codeclared_lemmas = all_lemmas - co_declared_lemmas
print(non_codeclared_lemmas)
lemmas_with_paragraph_content = 7994
lemmas_with_NO_paragraph_content = non_codeclared_lemmas - lemmas_with_paragraph_content
print(lemmas_with_NO_paragraph_content)
lemmas_with_TWOPLUS_paragraph_of_content = 7985
lemmas_with_ONE_paragraph_of_content = 9

final_usable_lemma_count = lemmas_with_TWOPLUS_paragraph_of_content #7985
# Out:
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:7777
# INFO:werkzeug:Press CTRL+C to quit
# 9570
# 8132
# 138
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <style>
#         .birdseye-iframe {
#             width: 100%;
#             height: 480px;
#         }
#
#         .birdseye-iframe > iframe {
#             width: 100%;
#             height: 98%;
#         }
#
#         .birdseye-iframe-resizer {
#             height: 10px;
#             width: 100%;
#             cursor: ns-resize;
#             background: lightgrey url("data:image/png;base64,...") no-repeat center;
#         }
#
#         .new-tab-link {
#             text-align: right;
#             font-size: 9pt;
#             font-family: sans-serif;
#         }
#
#         .new-tab-icon {
#             background: linear-gradient(transparent, transparent), url("data:image/svg+xml,%3Csvg xmlns=%22http://www.w3.org/2000/svg%22 width=%2212%22 height=%2212%22%3E %3Cpath fill=%22%23fff%22 stroke=%22%2336c%22 d=%22M1.5 4.518h5.982V10.5H1.5z%22/%3E %3Cpath fill=%22%2336c%22 d=%22M5.765 1H11v5.39L9.427 7.937l-1.31-1.31L5.393 9.35l-2.69-2.688 2.81-2.808L4.2 2.544z%22/%3E %3Cpath fill=%22%23fff%22 d=%22M9.995 2.004l.022 4.885L8.2 5.07 5.32 7.95 4.09 6.723l2.882-2.88-1.85-1.852z%22/%3E %3C/svg%3E") no-repeat center right;
#         }
#     </style>
# </head>
# <body>
#
# <div id="new-tab-link-52875617c560441395aadd6a4c03c5be" class="new-tab-link"></div>
# <div class="birdseye-iframe" id="52875617c560441395aadd6a4c03c5be">
#
#     <div class="birdseye-iframe-resizer" onmousedown="birdseyeIframeInitDrag(this, event)"></div>
# </div>
#
# <script>
#     // Based on https://stackoverflow.com/a/8960307/2482744
#     function birdseyeIframeInitDrag(resizer, event) {
#         var startY = event.clientY;
#         var container = resizer.parentNode;
#         var startHeight = parseInt(document.defaultView.getComputedStyle(container).height, 10);
#         var iframe = container.getElementsByTagName('iframe')[0];
#         iframe.style['pointer-events'] = 'none';
#
#         function doDrag(e) {
#             container.style.height = (startHeight + Math.max(10, e.clientY) - startY) + 'px';
#         }
#
#         function stopDrag() {
#             document.documentElement.removeEventListener('mousemove', doDrag, false);
#             document.documentElement.removeEventListener('mouseup', stopDrag, false);
#             iframe.style['pointer-events'] = 'auto';
#         }
#
#         document.documentElement.addEventListener('mousemove', doDrag, false);
#         document.documentElement.addEventListener('mouseup', stopDrag, false);
#     }
#
#     (function () {
#         var url;
#
#             var loc = window.location;
#             url = loc.protocol + "//" + loc.hostname + ':7777';
#
#         url += '/ipython_call/38449f0e956d4f2fbeb0013b9877afd4';
#         var container = document.getElementById('52875617c560441395aadd6a4c03c5be');
#         container.innerHTML = '<iframe src="' + url + '"></iframe>' + container.innerHTML;
#
#         container = document.getElementById('new-tab-link-52875617c560441395aadd6a4c03c5be');
#         container.innerHTML = '<a target="_blank" href="' + url + '">Open in new tab <i class="new-tab-icon">&nbsp;&nbsp;&nbsp;&nbsp;</i></a>';
#     })()
# </script>
#
# </body>
# </html>
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:23:56] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:23:56] "GET /static/css/main.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:23:56] "GET /static/css/bootstrap.min.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:23:56] "GET /static/js/libs/bootstrap.js HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:23:56] "GET /static/js/libs/jquery-3.2.1.js HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:23:56] "GET /static/img/logo.png HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:23:56] "GET /static/fonts/glyphicons-halflings-regular.woff2 HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:23:56] "GET /static/favicon.ico HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:02] "GET /call/38449f0e956d4f2fbeb0013b9877afd4 HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:02] "GET /static/css/main.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:02] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:02] "GET /static/js/libs/bootstrap.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:02] "GET /static/js/libs/jquery-3.2.1.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:02] "GET /static/css/proton/style.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:02] "GET /static/css/hljs.min.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:02] "GET /static/js/libs/highlight.pack.js HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:02] "GET /static/js/call.js HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:02] "GET /static/js/libs/underscore.js HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:02] "GET /static/img/logo.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:02] "GET /static/img/handle.png HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:02] "GET /static/js/libs/jstree.js HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:02] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3310990696.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3310990696.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:02] "GET /static/css/proton/throbber.gif HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:02] "GET /static/css/proton/fonts/titillium/titilliumweb-regular-webfont.woff HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:03] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3310990696.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3310990696.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:04] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3310990696.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3310990696.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:05] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3310990696.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3310990696.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:06] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3310990696.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3310990696.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:07] "GET /static/css/proton/32px.png HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:07] "GET /static/img/type_icons/int.png HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:07] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3310990696.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3310990696.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:08] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3310990696.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3310990696.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:09] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3310990696.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3310990696.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:10] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3310990696.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3310990696.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:11] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3310990696.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3310990696.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:24:12] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3310990696.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3310990696.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:06] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:06] "GET /static/css/main.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:06] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:06] "GET /static/js/libs/jquery-3.2.1.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:06] "GET /static/js/libs/bootstrap.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:06] "GET /static/img/logo.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:06] "GET /static/fonts/glyphicons-halflings-regular.woff2 HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:13] "GET /call/5a7767f78dd24cde98b1fe55d275f6a2 HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:13] "GET /static/css/main.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:13] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:13] "GET /static/js/libs/jquery-3.2.1.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:13] "GET /static/css/hljs.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:13] "GET /static/js/libs/bootstrap.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:13] "GET /static/css/proton/style.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:13] "GET /static/js/libs/highlight.pack.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:13] "GET /static/js/libs/jstree.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:13] "GET /static/js/libs/underscore.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:13] "GET /static/js/call.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:13] "GET /static/img/logo.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:13] "GET /static/img/handle.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:13] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3695885801.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3695885801.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:13] "GET /static/css/proton/throbber.gif HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:13] "GET /static/css/proton/fonts/titillium/titilliumweb-regular-webfont.woff HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:14] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3695885801.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3695885801.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:15] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3695885801.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_18540%5C3695885801.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:15] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:16] "GET /call/b3e16e1062a6430b98dc897f531d1aee HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:17] "GET /static/css/main.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:17] "GET /static/js/libs/jquery-3.2.1.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:17] "GET /static/css/hljs.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:17] "GET /static/css/bootstrap.min.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:17] "GET /static/js/libs/bootstrap.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:17] "GET /static/css/proton/style.css HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:17] "GET /static/js/libs/highlight.pack.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:17] "GET /static/js/libs/jstree.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:17] "GET /static/js/libs/underscore.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:17] "GET /static/js/call.js HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:17] "GET /static/img/logo.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:17] "GET /static/img/handle.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:17] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:17] "GET /static/css/proton/throbber.gif HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:18] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:19] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:20] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:21] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:22] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:23] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:24] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:25] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:26] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:27] "GET /static/css/proton/32px.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:27] "GET /static/img/type_icons/int.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:27] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:28] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:29] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:30] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:31] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:32] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:33] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:34] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:35] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:36] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:37] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:38] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:39] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:40] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:41] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:42] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:43] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:44] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:45] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:46] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:47] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:48] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:49] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:51] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:52] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:53] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:54] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:55] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:56] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:57] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:58] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:33:59] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:00] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:01] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:02] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:03] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:04] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:05] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:06] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:07] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:08] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:09] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:10] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:11] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:12] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:13] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:14] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:15] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:16] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:17] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:18] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:19] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:20] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:21] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:22] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:24] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:25] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:26] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:27] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:28] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:29] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:30] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:31] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:32] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:33] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:34] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:35] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:36] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:37] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:38] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:39] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:40] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:41] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:42] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:43] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:44] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:45] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:46] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:47] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:48] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:49] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:50] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:51] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:52] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:53] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:54] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:55] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:56] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:57] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:58] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:34:59] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:00] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:01] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:02] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:03] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:04] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:05] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:06] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:07] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:08] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:09] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:10] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:11] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:12] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:13] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:14] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:15] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:16] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:17] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:18] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:19] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:20] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:21] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:22] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:23] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:24] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:25] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:26] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:27] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:35:28] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_17880%5C2582870823.py/latest_call/ HTTP/1.1" 200 -
# ...
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:08] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:09] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:10] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:11] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:12] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:13] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:14] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:15] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:15] "GET /static/img/type_icons/dict.png HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:16] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:16] "GET /static/img/type_icons/object.png HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:17] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:18] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:19] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:20] "GET /static/img/type_icons/int.png HTTP/1.1" 304 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:20] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:21] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:22] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:23] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:24] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:25] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:26] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:27] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:28] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:29] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:30] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:31] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:32] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:33] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:34] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:35] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:36] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:37] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:38] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:39] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:40] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:41] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:42] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:43] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:44] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:45] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:46] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:47] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:48] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:49] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:50] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:51] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:52] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:53] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:54] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:55] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:56] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:57] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:58] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:40:59] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:41:00] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:41:01] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:41:02] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:41:03] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:41:04] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:41:05] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Aug/2022 10:41:06] "GET /api/file/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/__function__/C:%5CUsers%5Cpeter%5CAppData%5CLocal%5CTemp%5Cipykernel_1676%5C3688769430.py/latest_call/ HTTP/1.1" 200 -

# %% [markdown]
# From the Kamusi Article
# >When parsing was completed, the source dictionary resolved to 7918 Fula entries and 10970 Fula senses.
#
# Current output of my parser pipeline?
# > my parser was able to find **67 more** entries than their parsing routine.
# >
# > Roots word pieces:    6381
# >
# > Root subword pieces: 713
# >
# > Lemmas:   7985 usable for two-way Wordnet Matching described in the article (9570 total)
